# %% [markdown]
# # Oneiros Engine Colab execution
# Run these 3 cells to install prerequisites and run the main Phase 4 AI DPO-Training Pipeline.

# %%
# 1. Install required machine-learning packages for Oneiros
# !pip install transformers torch peft trl faiss-cpu sentence-transformers mutmut pandas -q

# %%
# 2. Mount Google Drive so we have access to the Code
# (Upload the `oneiros` folder to `MyDrive/Capstone/oneiros` before running)
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Capstone/oneiros

# %%
# 3. Run the Main Pipeline Loop (Ensure we aren't using the Local Mock Generator)
# !sed -i 's/use_mock_generator=True/use_mock_generator=False/' oneiros_loop.py

# !python oneiros_loop.py
